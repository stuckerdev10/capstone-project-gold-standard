# %%
import requests
import pprint
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
f_key = 'EidCUpLYQjf99bfTaIHSy6RHhrHSyolczQJTihgW'

url = requests.get(f"https://api.ers.usda.gov/data/arms/state?api_key={f_key}")

url.json()
#f"https://api.ers.usda.gov/data/arms/surveydata?api_key={f_key}&year=2020,2019,2018,2017,2016,2015,2014,2013,2012,2011&state=ar,ca,fl,ga,il,in,ia,ks,mn,mo,ni,nc,tx,wa,wi&category=sal&category2=spec&report=structural+characteristics&variable=vprodtot"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[54]: {&#39;status&#39;: &#39;ok&#39;,
#  &#39;info&#39;: {&#39;timing&#39;: {&#39;executing&#39;: 0, &#39;unit&#39;: &#39;ms&#39;},
#   &#39;result_coverage&#39;: &#39;total&#39;,
#   &#39;total&#39;: {&#39;record_count&#39;: 16}},
#  &#39;data&#39;: [{&#39;id&#39;: &#39;00&#39;, &#39;code&#39;: &#39;all&#39;, &#39;name&#39;: &#39;All survey states&#39;},
#   {&#39;id&#39;: &#39;05&#39;, &#39;code&#39;: &#39;ar&#39;, &#39;name&#39;: &#39;Arkansas&#39;},
#   {&#39;id&#39;: &#39;06&#39;, &#39;code&#39;: &#39;ca&#39;, &#39;name&#39;: &#39;California&#39;},
# ...

# %%
f_key = 'EidCUpLYQjf99bfTaIHSy6RHhrHSyolczQJTihgW'
url = f"https://api.ers.usda.gov/data/arms/surveydata?api_key={f_key}&year=2020&state=ar,ca,fl,ga,il,in,ia,ks,mn,mo,ni,nc,tx,wa,wi&category=spec&report=structural+characteristics&variable=vprodtot"
response = requests.get(url)
pprint.pprint(response.json())
data = response.json()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;data&#39;: [{&#39;category&#39;: &#39;Production Specialty&#39;,
#            &#39;category2&#39;: &#39;All Farms&#39;,
#            &#39;category2_value&#39;: &#39;TOTAL&#39;,
#            &#39;category_value&#39;: &#39;General Cash Grains&#39;,
#            &#39;decimal_display&#39;: 0,
#            &#39;estimate&#39;: 549229.0,
#            &#39;farmtype&#39;: &#39;All Farms&#39;,
#            &#39;median&#39;: None,
#            &#39;report&#39;: &#39;Structural Characteristics&#39;,
#            &#39;rse&#39;: 17.5,
#            &#39;state&#39;: &#39;Wisconsin&#39;,
#            &#39;statistic&#39;: &#39;TOTAL&#39;,
# ...

# %%
import pandas as pd

df = pd.DataFrame(data['data'])
df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>year</th>
#       <th>state</th>
#       <th>report</th>
#       <th>farmtype</th>
#       <th>category</th>
#       <th>category_value</th>
#       <th>category2</th>
#       <th>category2_value</th>
#       <th>variable_id</th>
# ...

# %%
test = df.copy()[['state', 'category_value', 'estimate']]
test['estimate'].fillna(0, inplace = True)
test
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>category_value</th>
#       <th>estimate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Wisconsin</td>
#       <td>General Cash Grains</td>
#       <td>549229.0</td>
#     </tr>
# ...

# %%
farm_df = spark.createDataFrame(test)
display(farm_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
farm_df = farm_df.withColumnRenamed('category_value', 'Specialty')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
storageAccount = "gen10datafund2111"
storageContainer = "gold-standard"
clientSecret = "~bJ7Q~KslVT~sAmHkOLXL0oeTp1ZkAcndtHPr"
clientid = "2ca50102-5717-4373-b796-39d06568588d"
mount_point = "/mnt/gold-standard/"
#20200906-20201006/Detroit911-20200906-20201006.csv 


configs = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": clientid,
       "fs.azure.account.oauth2.client.secret": clientSecret,
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/d46b54b2-a652-420b-aa5a-2ef7f8fc706e/oauth2/token",
       "fs.azure.createRemoteFileSystemDuringInitialization": "true"}

try: 
    dbutils.fs.unmount(mount_point)
except:
    pass

dbutils.fs.mount(
source = "abfss://"+storageContainer+"@"+storageAccount+".dfs.core.windows.net/",
mount_point = mount_point,
extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/gold-standard/ has been unmounted.
# Out[45]: True</div>

# %%
farm_df.coalesce(1).write.option('header', True).format('csv').mode('overwrite').save('/mnt/gold-standard/farm-etl')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
url = f"https://api.ers.usda.gov/data/arms/surveydata?api_key={f_key}&year=2020&state=mn&category=sal&category2=spec&report=structural+characteristics&variable=kount"

response = requests.get(url)
mn_json = response.json()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mn_json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: {&#39;status&#39;: &#39;ok&#39;,
#  &#39;info&#39;: {&#39;timing&#39;: {&#39;executing&#39;: 128, &#39;unit&#39;: &#39;ms&#39;},
#   &#39;result_coverage&#39;: &#39;total&#39;,
#   &#39;total&#39;: {&#39;record_count&#39;: 45}},
#  &#39;data&#39;: [{&#39;year&#39;: 2020,
#    &#39;state&#39;: &#39;Minnesota&#39;,
#    &#39;report&#39;: &#39;Structural Characteristics&#39;,
#    &#39;farmtype&#39;: &#39;All Farms&#39;,
#    &#39;category&#39;: &#39;Economic Class&#39;,
#    &#39;category_value&#39;: &#39;$500,000 to $999,999&#39;,
#    &#39;category2&#39;: &#39;Production Specialty&#39;,
# ...

# %%
mn_df = pd.DataFrame(mn_json['data'])
mn_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[49]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>year</th>
#       <th>state</th>
#       <th>report</th>
#       <th>farmtype</th>
#       <th>category</th>
#       <th>category_value</th>
#       <th>category2</th>
#       <th>category2_value</th>
#       <th>variable_id</th>
# ...

# %%
mn_df = mn_df.copy()[['state', 'category_value', 'category2_value', 'estimate']]
mn_df['estimate'].fillna(0, inplace = True)
mn_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>category_value</th>
#       <th>category2_value</th>
#       <th>estimate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Minnesota</td>
#       <td>$500,000 to $999,999</td>
# ...

# %%
mn_spark = spark.createDataFrame(mn_df)
mn_spark = mn_spark.withColumnRenamed('category_value', 'Income Class').withColumnRenamed('category2_value', 'Specialty')
display(mn_spark)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
mn_spark.coalesce(1).write.option('header', True).format('csv').mode('overwrite').save('/mnt/gold-standard/mn-etl')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
old_name = dbutils.fs.ls('mnt/gold-standard/mn-etl')[3].name
new_name = 'TEST-RENAME.csv'

dbutils.fs.mv()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[58]: &#39;mn-etl.csv&#39;</div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
